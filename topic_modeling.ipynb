# %% [markdown]
# ## Imports

# %%
from bertopic import BERTopic
import pandas as pd
import re
import json
from sentence_transformers import SentenceTransformer
import torch
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from top2vec import Top2Vec

# %% [markdown]
# ## Import Data

# %%
combined_df = pd.read_csv("data/csv/combined_terms.csv")

combined_df.head()
# Out:
#          date                        topic  \
# 0  07-05-1999                     1. VOTES
# 1  07-05-1999             2. Potato starch
# 2  07-05-1999             3. Hannover 2000
# 3  07-05-1999  4. European textiles market
# 4  06-05-1999   1. Approval of the Minutes
#
#                                                 text   term
# 0  President . – We shall now move on to the vote...  94_99
# 1  President . – The next item is the proposal fo...  94_99
# 2  President . – The next item is the report (A4‐...  94_99
# 3  President . – The next item is the joint debat...  94_99
# 4  President . – The Minutes of yesterday's sitti...  94_99

# %%
print(combined_df.shape)
# Out:
# (23408, 4)

# %% [markdown]
# ## BERTopic Model

# %%
# for CPU usage
# bertopic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
print(torch.cuda.is_available())  # Should be True
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 4070 Laptop GPU

# %%
if torch.cuda.is_available():
    # run with GPU
    print("Using GPU")
    embedding_model = SentenceTransformer("all-MiniLM-L6-v2", device="cuda")
    bertopic_model = BERTopic(embedding_model=embedding_model)
else:
    # run with CPU
    print("Using CPU")
    bertopic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")
# Out:
# Using GPU
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
stop_words = ENGLISH_STOP_WORDS

# %%
with open('data/custom_stopwords.json', 'r', encoding='utf-8') as f:
    custom_stopwords = set(json.load(f))

# %%
print(list(custom_stopwords)[:10])
# Out:
# ['decision', 'proposal', 'joint', 'nominee', 'honourable', 'floor', 'question', 'appendices', 'subject', 'vicepresident']

# %%
# Combine with sklearn stopwords
stop_words = ENGLISH_STOP_WORDS.union(custom_stopwords)

# %%
def clean_text(text):
    # Lowercase
    text = text.lower()
    # Remove punctuation, numbers, etc.
    text = re.sub(r"[^a-z\s]", "", text)
    # Remove stopwords
    text = " ".join([word for word in text.split() if word not in stop_words])
    return text

# %%
df = combined_df.copy()

# %%
df["clean_text"] = df["text"].apply(clean_text)
docs = df["clean_text"].tolist()

# %%
df["clean_text"].head()
# Out:
# 0    shall votes regulation ecsc ec euratom incorpo...
# 1    regulation amending regulation ec establishing...
# 2    hoppenstedt culture youth education media comm...
# 3    following b ferrer peijs chanterie group peopl...
# 4    distributed spencer ppe chairman foreign affai...
# Name: clean_text, dtype: object

# %%
for idx in range(10):
    text = df.iloc[idx]["clean_text"]
    word_count = len(str(text).split())
    print(f"Row {idx}: {word_count} words")
# Out:
# Row 0: 514 words
# Row 1: 562 words
# Row 2: 1201 words
# Row 3: 2649 words
# Row 4: 480 words
# Row 5: 2324 words
# Row 6: 3796 words
# Row 7: 6870 words
# Row 8: 8430 words
# Row 9: 111 words

# %% [markdown]
# This might be an issue for BERTopic as it can only handle 512 tokens, so some information will be lost as the text will get truncated.

# %%
topics, probs = bertopic_model.fit_transform(docs)

# %%
topic_info = bertopic_model.get_topic_info()

topic_info
# Out:
#      Topic  Count                                           Name  \
# 0       -1   6917                  -1_europe_states_eu_countries
# 1        0    488             0_fishing_fisheries_fish_fishermen
# 2        1    409               1_women_gender_equality_violence
# 3        2    329      2_budget_budgets_budgetary_appropriations
# 4        3    297                                  3_la_di_le_il
# ..     ...    ...                                            ...
# 334    333     11            333_reads_objections_human_cautions
# 335    334     11         334_budget_refugee_million_flexibility
# 336    335     11   335_verbal_distributed_approved_observations
# 337    336     10  336_disease_vaccination_footandmouth_outbreak
# 338    337     10       337_endocrine_disruptors_dehp_substances
#
#                                         Representation  \
# 0    [europe, states, eu, countries, new, citizens,...
# 1    [fishing, fisheries, fish, fishermen, stocks, ...
# 2    [women, gender, equality, violence, men, women...
# 3    [budget, budgets, budgetary, appropriations, e...
# 4         [la, di, le, il, che, et, que, en, die, und]
# ..                                                 ...
# 334  [reads, objections, human, cautions, rights, b...
# 335  [budget, refugee, million, flexibility, migrat...
# 336  [verbal, distributed, approved, observations, ...
# 337  [disease, vaccination, footandmouth, outbreak,...
# 338  [endocrine, disruptors, dehp, substances, crit...
#
#                                    Representative_Docs
# 0    [outcome december presidentinoffice activity f...
# 1    [following reports stevenson fisheries communi...
# 2    [explanations voting michaela ojdrov ppe consi...
# 3    [following reports budgets costa neves draft g...
# 4    [presidente lordine del giorno reca discussion...
# ..                                                 ...
# 334  [violations human rights democracy rule law ec...
# 335  [voting isabella adinolfi efdd writing followi...
# 336  [verbal process approved texts distributed obs...
# 337  [following b van dam edd group footandmouth di...
# 338  [presidentthe point verbal answer matthias gro...
#
# [339 rows x 5 columns]

# %%
# Add topic assignments to dataframe
df["bertopic_topic"] = topics
df["bertopic_prob"] = probs

# %%
df.head()
# Out:
#          date                        topic  \
# 0  07-05-1999                     1. VOTES
# 1  07-05-1999             2. Potato starch
# 2  07-05-1999             3. Hannover 2000
# 3  07-05-1999  4. European textiles market
# 4  06-05-1999   1. Approval of the Minutes
#
#                                                 text   term  \
# 0  President . – We shall now move on to the vote...  94_99
# 1  President . – The next item is the proposal fo...  94_99
# 2  President . – The next item is the report (A4‐...  94_99
# 3  President . – The next item is the joint debat...  94_99
# 4  President . – The Minutes of yesterday's sitti...  94_99
#
#                                           clean_text  bertopic_topic  \
# 0  shall votes regulation ecsc ec euratom incorpo...              11
# 1  regulation amending regulation ec establishing...               4
# 2  hoppenstedt culture youth education media comm...              39
# 3  following b ferrer peijs chanterie group peopl...             235
# 4  distributed spencer ppe chairman foreign affai...              -1
#
#    bertopic_prob
# 0       0.155931
# 1       0.273608
# 2       0.194263
# 3       1.000000
# 4       0.000000

# %%
for topic_num in bertopic_model.get_topics().keys():
    if topic_num == -1:  # skip outlier topic
        continue
    print(f"\nTopic {topic_num}")
    print([word for word, _ in bertopic_model.get_topic(topic_num)])
# Out:
# Topic 0
# ['fishing', 'fisheries', 'fish', 'fishermen', 'stocks', 'sea', 'tuna', 'waters', 'marine', 'species']
#
# Topic 1
# ['women', 'gender', 'equality', 'violence', 'men', 'womens', 'equal', 'girls', 'sexual', 'female']
#
# Topic 2
# ['budget', 'budgets', 'budgetary', 'appropriations', 'expenditure', 'eur', 'financial', 'year', 'funds', 'billion']
#
# Topic 3
# ['la', 'di', 'le', 'il', 'che', 'et', 'que', 'en', 'die', 'und']
#
# Topic 4
# ['farmers', 'agricultural', 'agriculture', 'rural', 'milk', 'production', 'cap', 'producers', 'food', 'dairy']
#
# Topic 5
# ['energy', 'renewable', 'gas', 'electricity', 'efficiency', 'sources', 'supply', 'market', 'prices', 'energies']
#
# Topic 6
# ['delegation', 'gallery', 'interparliamentary', 'pleasure', 'warm', 'visit', 'strasbourg', 'fruitful', 'led', 'wish']
#
# Topic 7
# ['que', 'la', 'en', 'el', 'los', 'para', 'las', 'por', 'se', 'una']
#
# Topic 8
# ['la', 'et', 'les', 'le', 'des', 'en', 'que', 'nous', 'pour', 'qui']
#
# Topic 9
# ['social', 'employment', 'workers', 'labour', 'unemployment', 'labor', 'work', 'employees', 'working', 'jobs']
#
# Topic 10
# ['details', 'results', 'congratulations', 'result', 'good', '', '', '', '', '']
#
# Topic 11
# ['com', 'pse', 'directive', 'fr', 'community', 'writing', 'fatuzzo', 'adopted', 'sv', 'ppede']
#
# Topic 12
# ['israel', 'palestinian', 'israeli', 'gaza', 'peace', 'palestinians', 'hamas', 'palestine', 'middle', 'east']
#
# Topic 13
# ['disasters', 'solidarity', 'floods', 'fund', 'natural', 'disaster', 'affected', 'damage', 'fires', 'earthquake']
#
# Topic 14
# ['asylum', 'refugees', 'migration', 'migrants', 'immigration', 'refugee', 'seekers', 'immigrants', 'solidarity', 'mediterranean']
#
# Topic 15
# ['euro', 'monetary', 'ecb', 'stability', 'bank', 'central', 'currency', 'economic', 'pact', 'growth']
#
# Topic 16
# ['wednesday', 'request', 'thursday', 'presidents', 'group', 'conference', 'tuesday', 'partsession', 'afternoon', 'house']
#
# Topic 17
# ['voting', 'rollcall', 'votes', 'list', 'ask', 'explanations', 'request', 'sorry', 'application', 'final']
#
# Topic 18
# ['food', 'meat', 'consumers', 'labelling', 'products', 'foods', 'origin', 'consumer', 'beef', 'animal']
#
# Topic 19
# ['climate', 'emissions', 'kyoto', 'change', 'paris', 'greenhouse', 'global', 'gas', 'cop', 'carbon']
#
# Topic 20
# ['tax', 'vat', 'evasion', 'taxation', 'taxes', 'fraud', 'avoidance', 'fiscal', 'companies', 'exchange']
#
# Topic 21
# ['air', 'aviation', 'airlines', 'passengers', 'airports', 'aircraft', 'safety', 'airport', 'flight', 'transport']
#
# Topic 22
# ['und', 'die', 'der', 'wir', 'das', 'la', 'des', 'den', 'auch', 'ist']
#
# Topic 23
# ['distributed', 'house', 'approved', 'point', 'ask', 'rule', 'rules', 'corrected', 'posselt', 'madam']
#
# Topic 24
# ['cohesion', 'regions', 'regional', 'territorial', 'funds', 'structural', 'policy', 'urban', 'local', 'development']
#
# Topic 25
# ['olaf', 'corruption', 'fraud', 'laundering', 'crime', 'money', 'prosecutors', 'criminal', 'organized', 'office']
#
# Topic 26
# ['english', 'word', 'version', 'accepted', 'translation', 'words', 'propose', 'sentence', 'read', 'ppede']
#
# Topic 27
# ['vehicles', 'cars', 'emissions', 'car', 'automotive', 'industry', 'manufacturers', 'emission', 'noise', 'vehicle']
#
# Topic 28
# ['ukraine', 'ukrainian', 'russia', 'russian', 'war', 'ukraines', 'ukrainians', 'crimea', 'putin', 'association']
#
# Topic 29
# ['congo', 'rwanda', 'congolese', 'drc', 'african', 'republic', 'democratic', 'elections', 'violence', 'kabila']
#
# Topic 30
# ['consumer', 'consumers', 'market', 'products', 'internal', 'protection', 'product', 'directive', 'safety', 'goods']
#
# Topic 31
# ['banking', 'banks', 'financial', 'rating', 'credit', 'supervision', 'basel', 'markets', 'bank', 'capital']
#
# Topic 32
# ['turkey', 'turkish', 'turkeys', 'kurdish', 'accession', 'cyprus', 'trkiye', 'journalists', 'negotiations', 'freedom']
#
# Topic 33
# ['development', 'poverty', 'aid', 'developing', 'countries', 'goals', 'sustainable', 'millennium', 'coherence', 'global']
#
# Topic 34
# ['defense', 'defence', 'security', 'nato', 'military', 'foreign', 'policy', 'common', 'peace', 'threats']
#
# Topic 35
# ['children', 'child', 'convention', 'hague', 'minors', 'parents', 'childrens', 'abduction', 'sexual', 'internet']
#
# Topic 36
# ['road', 'vehicles', 'drivers', 'ecall', 'safety', 'traffic', 'roads', 'driving', 'transport', 'vehicle']
#
# Topic 37
# ['smes', 'investment', 'eib', 'small', 'enterprises', 'bank', 'capital', 'investments', 'financing', 'projects']
#
# Topic 38
# ['immunity', 'deputy', 'parliamentary', 'lifting', 'request', 'alleged', 'privileges', 'offense', 'immunities', 'mep']
#
# Topic 39
# ['cultural', 'culture', 'heritage', 'creative', 'languages', 'diversity', 'language', 'programme', 'linguistic', 'creativity']
#
# Topic 40
# ['globalization', 'workers', 'fund', 'mobilization', 'egf', 'dismissed', 'feg', 'adjustment', 'labor', 'reintegration']
#
# Topic 41
# ['data', 'personal', 'protection', 'privacy', 'pnr', 'exchange', 'automated', 'terrorism', 'agreement', 'united']
#
# Topic 42
# ['referral', 'interinstitutional', 'request', 'negotiations', 'rckberweisung', 'antrag', 'refer', 'rule', 'den', 'approved']
#
# Topic 43
# ['belarus', 'belarusian', 'lukashenko', 'prisoners', 'opposition', 'regime', 'elections', 'minsk', 'democratic', 'belarusians']
#
# Topic 44
# ['discharge', 'budget', 'agency', 'accounts', 'auditors', 'execution', 'court', 'management', 'financial', 'annual']
#
# Topic 45
# ['medicines', 'patients', 'medicinal', 'medical', 'devices', 'pharmaceutical', 'products', 'health', 'clinical', 'patient']
#
# Topic 46
# ['environmental', 'environment', 'programme', 'directive', 'damage', 'legislation', 'life', 'public', 'rhus', 'liability']
#
# Topic 47
# ['law', 'legal', 'favour', 'shale', 'disputes', 'writing', 'regulation', 'justice', 'legislation', 'citizens']
#
# Topic 48
# ['pentru', 'din', 'este', 'nu', 'mai', 'pe', 'care', 'cu', 'trebuie', 'la']
#
# Topic 49
# ['ballot', 'votes', 'candidates', 'election', 'cast', 'vicepresidents', 'elected', 'tellers', 'quaestors', 'candidacies']
#
# Topic 50
# ['human', 'rights', 'democracy', 'world', 'violations', 'freedom', 'representative', 'defenders', 'countries', 'universal']
#
# Topic 51
# ['je', 'jsem', 'na', 'kter', 'se', 'evropsk', 'la', 'tak', 'pro', 'en']
#
# Topic 52
# ['waste', 'plastic', 'bags', 'recycling', 'packaging', 'plastics', 'environment', 'environmental', 'directive', 'hazardous']
#
# Topic 53
# ['china', 'chinese', 'hong', 'kong', 'tibet', 'tibetan', 'human', 'rights', 'dalai', 'lama']
#
# Topic 54
# ['pursuant', 'negotiations', 'enter', 'webpage', 'committees', 'threshold', 'midnight', 'interinstitutional', 'reaching', 'request']
#
# Topic 55
# ['die', 'und', 'la', 'der', 'que', 'en', 'wir', 'des', 'et', 'le']
#
# Topic 56
# ['citizens', 'legislative', 'institutions', 'transparency', 'initiative', 'acts', 'legislation', 'interinstitutional', 'regulation', 'administration']
#
# Topic 57
# ['abstimmungsrunde', 'uhr', 'abstimmungen', 'abstimmen', 'die', 'bis', 'zur', 'erffnet', 'abstimmungsverfahren', 'ergebnisse']
#
# Topic 58
# ['li', 'program', 'la', 'ta', 'volunteering', 'que', 'en', 'die', 'erasmus', 'et']
#
# Topic 59
# ['digital', 'competition', 'market', 'single', 'services', 'consumers', 'online', 'internet', 'economy', 'companies']
#
# Topic 60
# ['genetically', 'modified', 'gmos', 'gmo', 'glyphosate', 'objection', 'cultivation', 'corn', 'food', 'authorization']
#
# Topic 61
# ['latin', 'peru', 'america', 'ecuador', 'colombia', 'mercosur', 'agreement', 'trade', 'mexico', 'chile']
#
# Topic 62
# ['georgia', 'georgian', 'georgias', 'caucasus', 'russia', 'abkhazia', 'ossetia', 'russian', 'south', 'georgians']
#
# Topic 63
# ['chemicals', 'substances', 'chemical', 'toys', 'reach', 'environment', 'health', 'mercury', 'dangerous', 'directive']
#
# Topic 64
# ['transport', 'infrastructure', 'mobility', 'traffic', 'transeuropean', 'projects', 'networks', 'road', 'network', 'multimodal']
#
# Topic 65
# ['burma', 'myanmar', 'burmese', 'suu', 'rohingya', 'aung', 'kyi', 'san', 'junta', 'military']
#
# Topic 66
# ['croatia', 'accession', 'croatias', 'croatian', 'adhesion', 'membership', 'republic', 'agreement', 'slovenia', 'convention']
#
# Topic 67
# ['criminal', 'warrant', 'arrest', 'suspects', 'justice', 'judicial', 'legal', 'innocence', 'accused', 'proceedings']
#
# Topic 68
# ['roaming', 'internet', 'telecommunications', 'neutrality', 'mobile', 'communications', 'spectrum', 'digital', 'operators', 'electronic']
#
# Topic 69
# ['railway', 'rail', 'transport', 'railways', 'freight', 'passenger', 'interoperability', 'package', 'train', 'passengers']
#
# Topic 70
# ['ireland', 'irish', 'northern', 'peace', 'presidency', 'taoiseach', 'treaty', 'dublin', 'process', 'constitution']
#
# Topic 71
# ['schengen', 'border', 'borders', 'frontex', 'external', 'guard', 'agency', 'coast', 'controls', 'immigration']
#
# Topic 72
# ['patients', 'health', 'healthcare', 'cancer', 'care', 'diseases', 'patient', 'treatment', 'rare', 'disease']
#
# Topic 73
# ['nuclear', 'power', 'chernobyl', 'radioactive', 'safety', 'plants', 'reactors', 'decommissioning', 'energy', 'stations']
#
# Topic 74
# ['syria', 'syrian', 'humanitarian', 'assad', 'refugees', 'syrians', 'conflict', 'war', 'regime', 'civilians']
#
# Topic 75
# ['research', 'innovation', 'programme', 'horizon', 'researchers', 'program', 'excellence', 'framework', 'science', 'eit']
#
# Topic 76
# ['hungary', 'hungarian', 'orbn', 'law', 'values', 'government', 'rule', 'prime', 'fundamental', 'viktor']
#
# Topic 77
# ['na', 'la', 'que', 'und', 'die', 'en', 'der', 'si', 'jest', 'wir']
#
# Topic 78
# ['schulz', 'pm', 'martin', 'open', 'vorsitz', 'opened', 'david', 'nbsp', 'roca', 'vidalquadras']
#
# Topic 79
# ['education', 'erasmus', 'students', 'higher', 'bologna', 'mobility', 'training', 'universities', 'young', 'learning']
#
# Topic 80
# ['venezuela', 'venezuelan', 'maduro', 'venezuelans', 'opposition', 'democratic', 'government', 'chvez', 'elections', 'political']
#
# Topic 81
# ['thank', 'house', 'madam', 'audy', 'anthem', 'imbeni', 'work', 'approved', 'presidency', 'wanted']
#
# Topic 82
# ['health', 'asbestos', 'workers', 'safety', 'selfemployed', 'workplace', 'exposure', 'occupational', 'work', 'directive']
#
# Topic 83
# ['statute', 'corbett', 'rules', 'censure', 'groups', 'commissioners', 'house', 'rothley', 'group', 'majority']
#
# Topic 84
# ['silence', 'victims', 'condolences', 'sympathy', 'families', 'rose', 'terrorism', 'express', 'injured', 'attack']
#
# Topic 85
# ['russia', 'russian', 'partnership', 'eastern', 'summit', 'relations', 'russias', 'chechnya', 'ukraine', 'georgia']
#
# Topic 86
# ['madam', 'cyprus', 'cypriots', 'pse', 'house', 'bureau', 'matter', 'ask', 'point', 'laeken']
#
# Topic 87
# ['disabilities', 'disabled', 'accessibility', 'disability', 'persons', 'people', 'websites', 'blind', 'convention', 'accessible']
#
# Topic 88
# ['kosovo', 'kosovos', 'serbia', 'milosevic', 'serbian', 'stabilization', 'balkans', 'association', 'serbs', 'belgrade']
#
# Topic 89
# ['animal', 'animals', 'welfare', 'pets', 'pet', 'breeding', 'diseases', 'health', 'dogs', 'cats']
#
# Topic 90
# ['uzbekistan', 'kazakhstan', 'patent', 'kyrgyzstan', 'asia', 'uzbek', 'central', 'cotton', 'agreement', 'tajikistan']
#
# Topic 91
# ['humanitarian', 'tax', 'agus', 'children', 'education', 'writing', 'budget', 'ar', 'seo', 'aid']
#
# Topic 92
# ['sudan', 'south', 'sudanese', 'darfur', 'humanitarian', 'chad', 'african', 'conflict', 'peace', 'khartoum']
#
# Topic 93
# ['italian', 'italy', 'florence', 'presidency', 'europe', 'minister', 'rome', 'roma', 'government', 'prime']
#
# Topic 94
# ['water', 'drinking', 'groundwater', 'substances', 'bathing', 'directive', 'quality', 'pollution', 'waters', 'clean']
#
# Topic 95
# ['tunisia', 'tunisian', 'olive', 'oil', 'arab', 'morocco', 'tunisias', 'democratic', 'transition', 'country']
#
# Topic 96
# ['pttering', 'opened', 'pm', 'poettering', 'rack', 'rung', 'declare', 'scrates', 'thursday', 'floors']
#
# Topic 97
# ['discharge', 'budget', 'execution', 'agency', 'annual', 'auditors', 'financial', 'court', 'accounts', 'year']
#
# Topic 98
# ['fontaine', 'opened', 'pm', 'lfec', 'thursday', 'pavarotti', 'luciano', 'warrant', 'distributed', 'bethell']
#
# Topic 99
# ['fontelles', 'borrell', 'opened', 'pm', 'formal', 'applause', 'noon', 'concludes', 'suspended', 'explanations']
#
# Topic 100
# ['details', 'voting', 'results', 'time', 'longest', 'sessions', 'detailed', 'starting', 'history', '']
#
# Topic 101
# ['azerbaijan', 'armenia', 'nagornokarabakh', 'azerbaijani', 'baku', 'armenian', 'aliyev', 'human', 'caucasus', 'partnership']
#
# Topic 102
# ['verbal', 'bears', 'voting', 'details', 'turn', 'concern', 'results', 'process', 'sequel', 'shift']
#
# Topic 103
# ['moldova', 'moldovan', 'republic', 'moldovas', 'transnistria', 'association', 'russia', 'chiinu', 'russian', 'reforms']
#
# Topic 104
# ['drugs', 'drug', 'alcohol', 'substances', 'psychoactive', 'substance', 'consumption', 'control', 'precursors', 'synthetic']
#
# Topic 105
# ['iran', 'iranian', 'regime', 'death', 'amini', 'mahsa', 'human', 'executions', 'nuclear', 'rights']
#
# Topic 106
# ['je', 'na', 'da', 'za', 'se', 'la', 'que', 'und', 'die', 'der']
#
# Topic 107
# ['russia', 'russian', 'navalny', 'putin', 'memorial', 'alexei', 'boris', 'human', 'nemtsov', 'rights']
#
# Topic 108
# ['somalia', 'ethiopia', 'eritrea', 'kenya', 'ethiopian', 'somali', 'horn', 'kenyan', 'tigray', 'eritrean']
#
# Topic 109
# ['cox', 'opened', 'pm', 'lithuania', 'formal', 'queen', 'declare', 'afternoon', 'thursday', 'paksas']
#
# Topic 110
# ['discharge', 'execution', 'budget', 'agency', 'court', 'auditors', 'agencies', 'accounts', 'financial', 'annual']
#
# Topic 111
# ['trade', 'japan', 'gsp', 'agreement', 'wto', 'india', 'agreements', 'countries', 'free', 'korea']
#
# Topic 112
# ['thursday', 'presidents', 'wednesday', 'pursuant', 'distributed', 'conference', 'calendar', 'tuesday', 'partsessions', 'draft']
#
# Topic 113
# ['arms', 'weapons', 'cluster', 'exports', 'export', 'munitions', 'code', 'conventional', 'trade', 'uranium']
#
# Topic 114
# ['forests', 'forest', 'forestry', 'wood', 'timber', 'deforestation', 'palm', 'fires', 'tropical', 'climate']
#
# Topic 115
# ['saudi', 'bahrain', 'arabia', 'bahraini', 'human', 'rights', 'arab', 'yemen', 'activists', 'rajab']
#
# Topic 116
# ['zimbabwe', 'mugabe', 'mugabes', 'zimbabwean', 'african', 'elections', 'zimbabwes', 'africa', 'opposition', 'sadc']
#
# Topic 117
# ['cybersecurity', 'cyber', 'security', 'digital', 'defense', 'information', 'tiktok', 'networks', 'disinformation', 'network']
#
# Topic 118
# ['silence', 'rose', 'observed', 'memory', 'observe', 'house', 'died', 'sad', 'death', 'fellow']
#
# Topic 119
# ['customs', 'code', 'goods', 'sanctions', 'trade', 'legal', 'temporarily', 'authorities', 'regulation', 'application']
#
# Topic 120
# ['egypt', 'egyptian', 'egyptians', 'muslim', 'human', 'morsi', 'rights', 'arab', 'mubarak', 'brotherhood']
#
# Topic 121
# ['sitzung', 'verffentlicht', 'verfgbar', 'uhr', 'der', 'tagesordnung', 'morgen', 'die', 'heutigen', 'parlaments']
#
# Topic 122
# ['cuba', 'cuban', 'cubans', 'dialogue', 'prisoners', 'havana', 'human', 'castro', 'political', 'regime']
#
# Topic 123
# ['texts', 'approved', 'available', 'sittings', 'adopted', 'case', 'objectionsthat', 'candidatures', 'january', 'piorno']
#
# Topic 124
# ['bosnia', 'herzegovina', 'dayton', 'bosniaherzegovina', 'bih', 'country', 'bosnian', 'reforms', 'srpska', 'republika']
#
# Topic 125
# ['terrorism', 'terrorist', 'radicalization', 'terrorists', 'internet', 'attacks', 'fight', 'security', 'radicalisation', 'threat']
#
# Topic 126
# ['macedonia', 'yugoslav', 'macedonian', 'republic', 'fyrom', 'country', 'skopje', 'accession', 'negotiations', 'greece']
#
# Topic 127
# ['afghanistan', 'afghan', 'taliban', 'kabul', 'women', 'afghans', 'pakistan', 'girls', 'country', 'talibans']
#
# Topic 128
# ['roma', 'discrimination', 'integration', 'gypsy', 'inclusion', 'ethnic', 'minority', 'gypsies', 'strategies', 'education']
#
# Topic 129
# ['maritime', 'ships', 'sea', 'safety', 'seafarers', 'shipping', 'coastal', 'marine', 'vessels', 'erika']
#
# Topic 130
# ['la', 'vaccines', 'vaccine', 'covid', 'que', 'virus', 'pandemic', 'vaccination', 'en', 'die']
#
# Topic 131
# ['presidency', 'prime', 'danish', 'minister', 'finnish', 'enlargement', 'europe', 'finland', 'swedish', 'copenhagen']
#
# Topic 132
# ['vacancy', 'notified', 'election', 'competent', 'replacing', 'enjoyment', 'seat', 'effect', 'credentials', 'seats']
#
# Topic 133
# ['audiovisual', 'television', 'film', 'media', 'films', 'cinema', 'broadcasting', 'cultural', 'advertising', 'diversity']
#
# Topic 134
# ['cyprus', 'cypriot', 'turkish', 'turkey', 'cypriots', 'presidency', 'island', 'republic', 'christofias', 'occupation']
#
# Topic 135
# ['food', 'malnutrition', 'hunger', 'nutrition', 'prices', 'agricultural', 'agriculture', 'million', 'world', 'aid']
#
# Topic 136
# ['ombudsman', 'complaints', 'ombudsmans', 'petitions', 'institutions', 'oreilly', 'citizens', 'transparency', 'administration', 'diamandouros']
#
# Topic 137
# ['sport', 'sports', 'football', 'clubs', 'sporting', 'doping', 'fifa', 'olympic', 'players', 'games']
#
# Topic 138
# ['romania', 'romanian', 'romanians', 'government', 'corruption', 'rule', 'romanias', 'pentru', 'law', 'iohannis']
#
# Topic 139
# ['website', 'published', 'tomorrow', 'available', 'thursday', 'wednesday', 'chairwoman', 'parliaments', 'begin', 'november']
#
# Topic 140
# ['votazioni', 'turno', 'alle', 'svolgeranno', 'aperto', 'di', 'secondo', 'seduta', 'sospesa', 'sar']
#
# Topic 141
# ['iraq', 'iraqi', 'saddam', 'hussein', 'iraqs', 'war', 'united', 'iraqis', 'weapons', 'baghdad']
#
# Topic 142
# ['lesson', 'voting', 'details', 'follows', 'results', 'point', 'anneli', 'jtteenmki', 'strasbourgso', 'urquiza']
#
# Topic 143
# ['och', 'det', 'vi', 'att', 'som', 'en', 'har', 'till', 'la', 'der']
#
# Topic 144
# ['libya', 'libyan', 'gaddafi', 'libyans', 'tripoli', 'situation', 'country', 'region', 'libyas', 'migrants']
#
# Topic 145
# ['suspended', 'pm', 'evelyne', 'gebhardt', 'guillaume', 'sylvie', 'isabelle', 'adinaioana', 'vlean', 'vice']
#
# Topic 146
# ['lisbon', 'strategy', 'growth', 'social', 'barroso', 'europe', 'employment', 'jobs', 'economic', 'summit']
#
# Topic 147
# ['nuclear', 'korea', 'north', 'weapons', 'nonproliferation', 'korean', 'disarmament', 'treaty', 'proliferation', 'npt']
#
# Topic 148
# ['wieland', 'rainer', 'suspended', 'vice', 'pm', 'concludes', 'resumes', 'backsliding', 'zile', 'resume']
#
# Topic 149
# ['penalty', 'death', 'punishment', 'moratorium', 'torture', 'executions', 'abolition', 'capital', 'human', 'goods']
#
# Topic 150
# ['housing', 'poverty', 'homelessness', 'social', 'homeless', 'exclusion', 'income', 'people', 'minimum', 'affordable']
#
# Topic 151
# ['cambodia', 'cambodian', 'thailand', 'opposition', 'laos', 'asean', 'rainsy', 'elections', 'thai', 'human']
#
# Topic 152
# ['prize', 'sakharov', 'freedom', 'oleg', 'award', 'awarded', 'jia', 'salih', 'osman', 'thought']
#
# Topic 153
# ['europol', 'crime', 'organized', 'strategic', 'cooperation', 'exchange', 'operational', 'police', 'criminal', 'fight']
#
# Topic 154
# ['abstimmung', 'sonstige', 'einzelheiten', 'abstimmungsergebnisse', 'siehe', 'protokoll', 'tagesordnung', 'nchster', 'punkt', 'folgt']
#
# Topic 155
# ['basque', 'eta', 'silence', 'spanish', 'spain', 'terrorism', 'rose', 'condolences', 'carpena', 'sympathy']
#
# Topic 156
# ['vice', 'pm', 'suspended', 'esside', 'sisis', 'gllpelcz', 'valcrcel', 'graf', 'interrupted', 'ramn']
#
# Topic 157
# ['chairman', 'deputy', 'suspended', 'telika', 'pm', 'interrupted', 'pavel', 'honvidmaria', 'presidency', 'sassoli']
#
# Topic 158
# ['legislative', 'request', 'postponed', 'referred', 'postpone', 'final', 'negotiations', 'postponement', 'defer', 'trialogue']
#
# Topic 159
# ['auditors', 'court', 'error', 'errors', 'expenditure', 'annual', 'control', 'funds', 'audit', 'budget']
#
# Topic 160
# ['wto', 'doha', 'trade', 'round', 'developing', 'negotiations', 'multilateral', 'countries', 'cancn', 'world']
#
# Topic 161
# ['appointment', 'court', 'auditors', 'candidate', 'audit', 'candidates', 'professional', 'jakobsen', 'nomination', 'auditor']
#
# Topic 162
# ['protokoll', 'gestrigen', 'sitzung', 'genehmigt', 'einwnde', 'angenommenen', 'verfgbar', 'texte', 'das', 'der']
#
# Topic 163
# ['unterbrochen', 'mstopedsedkyn', 'sitzung', 'pedsednictv', 'uhr', 'charanzov', 'dita', 'wird', 'um', 'katarina']
#
# Topic 164
# ['youth', 'young', 'unemployment', 'education', 'people', 'employment', 'training', 'guarantee', 'skills', 'initiative']
#
# Topic 165
# ['bulgaria', 'romania', 'accession', 'bulgarian', 'romanian', 'bulgarias', 'romanias', 'corruption', 'enlargement', 'january']
#
# Topic 166
# ['racism', 'xenophobia', 'hate', 'antisemitism', 'hatred', 'semitism', 'anti', 'racist', 'intolerance', 'jewish']
#
# Topic 167
# ['air', 'pollution', 'pollutants', 'emissions', 'combustion', 'ozone', 'emission', 'methane', 'quality', 'limit']
#
# Topic 168
# ['malta', 'daphne', 'caruana', 'galizia', 'maltese', 'journalists', 'li', 'citizenship', 'journalist', 'murder']
#
# Topic 169
# ['africa', 'african', 'ghana', 'summit', 'migration', 'development', 'cinema', 'partnership', 'fund', 'euafrica']
#
# Topic 170
# ['het', 'van', 'en', 'een', 'dat', 'te', 'voor', 'die', 'la', 'op']
#
# Topic 171
# ['urgent', 'wogau', 'request', 'monetary', 'threemonth', 'partsession', 'affairs', 'amending', 'directive', 'urgency']
#
# Topic 172
# ['schulz', 'martin', 'pm', 'suspended', 'interrupted', 'schmitt', 'solemn', 'messageon', 'dellonmartin', 'momentcongratulations']
#
# Topic 173
# ['trafficking', 'victims', 'beings', 'prostitution', 'forced', 'human', 'exploitation', 'women', 'sexual', 'slavery']
#
# Topic 174
# ['intellectual', 'property', 'counterfeiting', 'piracy', 'counterfeit', 'observatory', 'ipr', 'rights', 'protection', 'registers']
#
# Topic 175
# ['jerzy', 'buzek', 'opened', 'tehran', 'iran', 'publicity', 'potito', 'salatto', 'assassinate', 'dc']
#
# Topic 176
# ['polish', 'poland', 'rule', 'constitutional', 'law', 'tusk', 'tribunal', 'government', 'presidency', 'poles']
#
# Topic 177
# ['tobacco', 'smoking', 'cigarettes', 'products', 'health', 'cigarette', 'smuggling', 'smokers', 'illicit', 'smoke']
#
# Topic 178
# ['buzek', 'jerzy', 'suspended', 'manfred', 'weber', 'opened', 'christoforou', 'luck', 'moments', 'concludes']
#
# Topic 179
# ['la', 'que', 'die', 'und', 'le', 'en', 'et', 'der', 'wir', 'di']
#
# Topic 180
# ['objections', 'todays', 'approval', 'beginning', 'named', 'submitted', 'persons', 'bodies', 'forward', 'adopted']
#
# Topic 181
# ['volunteering', 'young', 'voluntary', 'volunteer', 'volunteers', 'youth', 'service', 'corps', 'solidarity', 'programme']
#
# Topic 182
# ['sdes', 'ir', 'vadtjs', 'tmeka', 'publicta', 'krtba', 'vietn', 'sde', 'pieejama', 'plkst']
#
# Topic 183
# ['details', 'outcome', 'detailed', 'information', '', '', '', '', '', '']
#
# Topic 184
# ['details', 'outcome', 'voting', 'time', 'concludes', 'protasiewicz', 'hourif', 'jacek', 'lauk', 'vice']
#
# Topic 185
# ['rights', 'human', 'fundamental', 'democracy', 'rule', 'law', 'mechanism', 'respect', 'values', 'freedom']
#
# Topic 186
# ['species', 'cites', 'wild', 'wildlife', 'flora', 'fauna', 'endangered', 'trade', 'invasive', 'ivory']
#
# Topic 187
# ['petitions', 'petition', 'water', 'citizens', 'petitioners', 'sanitation', 'right', 'initiative', 'citizen', 'rightwater']
#
# Topic 188
# ['company', 'directive', 'artists', 'legal', 'lawyers', 'resale', 'profession', 'law', 'companies', 'lehne']
#
# Topic 189
# ['albania', 'albanian', 'albanias', 'berisha', 'elections', 'progress', 'political', 'opposition', 'reforms', 'corruption']
#
# Topic 190
# ['strasbourg', 'calendar', 'seat', 'sessions', 'roma', 'brussels', 'headquarters', 'plenary', 'accession', 'turkey']
#
# Topic 191
# ['nicaragua', 'guatemala', 'ortega', 'mexico', 'nicaraguan', 'human', 'mexican', 'rights', 'impunity', 'guatemalan']
#
# Topic 192
# ['procurement', 'public', 'contracts', 'award', 'directives', 'criteria', 'rules', 'market', 'contract', 'procedures']
#
# Topic 193
# ['transatlantic', 'united', 'relations', 'american', 'relationship', 'trump', 'america', 'americans', 'euus', 'summit']
#
# Topic 194
# ['china', 'taiwan', 'chinese', 'chinas', 'euchina', 'relations', 'taiwanese', 'strategic', 'beijing', 'human']
#
# Topic 195
# ['texts', 'approved', 'available', 'adopted', 'availableare', 'intervene', 'nonethe', 'itnobody', 'observationsthere', 'february']
#
# Topic 196
# ['kratsatsagaropoulou', 'pm', 'suspended', 'opened', 'rodi', 'podest', 'dimitrakopoulou', 'protasiewicz', 'mircea', 'pacu']
#
# Topic 197
# ['lgbtiq', 'discrimination', 'homophobia', 'orientation', 'sexual', 'lgbt', 'hate', 'lgbti', 'gay', 'rights']
#
# Topic 198
# ['ports', 'port', 'shipping', 'transport', 'maritime', 'sea', 'services', 'selfhandling', 'competition', 'pilotage']
#
# Topic 199
# ['greece', 'greek', 'euro', 'eurogroup', 'debt', 'liquidity', 'greeks', 'growth', 'zone', 'monetary']
#
# Topic 200
# ['skills', 'training', 'education', 'vocational', 'learning', 'qualifications', 'lifelong', 'young', 'educational', 'recognition']
#
# Topic 201
# ['visa', 'exemption', 'agreement', 'short', 'stays', 'travel', 'days', 'visas', 'relations', 'stay']
#
# Topic 202
# ['voting', 'votes', 'open', 'files', 'pm', 'declare', 'roll', 'indicated', 'announced', 'sessions']
#
# Topic 203
# ['space', 'galileo', 'spatial', 'copernicus', 'satellite', 'gmes', 'satellites', 'security', 'navigation', 'program']
#
# Topic 204
# ['brexit', 'british', 'kingdom', 'uk', 'britain', 'united', 'ireland', 'withdrawal', 'referendum', 'leave']
#
# Topic 205
# ['pakistan', 'pakistani', 'blasphemy', 'religious', 'bibi', 'death', 'musharraf', 'pakistans', 'kashmir', 'minorities']
#
# Topic 206
# ['pm', 'fontelles', 'borrell', 'suspended', 'srborrell', 'friedrich', 'khlers', 'presidencia', 'formal', 'opens']
#
# Topic 207
# ['nigeria', 'boko', 'haram', 'nigerian', 'violence', 'christians', 'nigerias', 'religious', 'sharia', 'cancer']
#
# Topic 208
# ['serbia', 'serbian', 'kosovo', 'serbias', 'progress', 'belgrade', 'reforms', 'accession', 'process', 'balkans']
#
# Topic 209
# ['martnez', 'pm', 'suspended', 'miguel', 'angel', 'preside', 'vice', 'ngel', 'presides', 'interrupted']
#
# Topic 210
# ['details', 'results', 'concerning', 'camembert', 'cheeses', 'enrollment', 'chairmananother', 'faulty', 'screen', 'regarding']
#
# Topic 211
# ['details', 'proceed', 'approved', 'results', 'shall', 'rejected', 'votes', 'fourth', 'unusually', 'announcing']
#
# Topic 212
# ['mountain', 'regions', 'alpine', 'macroregional', 'region', 'strategy', 'danube', 'mountainous', 'cohesion', 'water']
#
# Topic 213
# ['interrupted', 'pm', 'explain', 'period', 'declare', 'igear', 'appendicitis', 'parliaments', 'merry', 'spectators']
#
# Topic 214
# ['pesticides', 'plant', 'pests', 'plants', 'pesticide', 'phytosanitary', 'products', 'citrus', 'harmful', 'organisms']
#
# Topic 215
# ['colombia', 'colombian', 'peace', 'farc', 'visa', 'conflict', 'colombians', 'process', 'agreement', 'armed']
#
# Topic 216
# ['corrigendum', 'corrigenda', 'webpage', 'deemed', 'pursuant', 'transmitted', 'announcement', 'plenary', 'threshold', 'published']
#
# Topic 217
# ['lebanon', 'lebanese', 'republic', 'euromediterranean', 'syria', 'israel', 'syrian', 'hezbollah', 'middle', 'unifil']
#
# Topic 218
# ['sri', 'maldives', 'lanka', 'tamil', 'lankan', 'ltte', 'nasheed', 'tigers', 'government', 'conflict']
#
# Topic 219
# ['war', 'peace', 'world', 'europe', 'soviet', 'history', 'nazi', 'remember', 'today', 'freedom']
#
# Topic 220
# ['schulz', 'opened', 'martin', 'berlinguer', 'roca', 'oldest', 'vidalquadras', 'mairead', 'mcguinness', 'declare']
#
# Topic 221
# ['burundi', 'madagascar', 'burundian', 'nkurunziza', 'african', 'arusha', 'elections', 'country', 'violence', 'situation']
#
# Topic 222
# ['banana', 'bananas', 'acp', 'rice', 'producers', 'wto', 'tariff', 'import', 'trade', 'quota']
#
# Topic 223
# ['chairman', 'ryszard', 'czarnecki', 'vice', 'suspended', 'pm', 'concludes', 'interrupted', 'voting', 'lesson']
#
# Topic 224
# ['crimes', 'court', 'criminal', 'icc', 'international', 'statute', 'genocide', 'rome', 'munitions', 'tribunal']
#
# Topic 225
# ['abstimmungsstunde', 'sitzung', 'unterbrochen', 'geschlossen', 'uhr', 'damit', 'wird', 'die', 'prsident', 'ist']
#
# Topic 226
# ['voting', 'chairman', 'details', 'results', 'point', 'votes', 'summary', 'day', 'order', 'sinclaire']
#
# Topic 227
# ['tourism', 'tourist', 'tourists', 'destination', 'sector', 'destinations', 'industry', 'philoxenia', 'cultural', 'cook']
#
# Topic 228
# ['growth', 'economic', 'guidelines', 'employment', 'monetary', 'pact', 'policy', 'stability', 'investment', 'broad']
#
# Topic 229
# ['iran', 'iranian', 'nuclear', 'irans', 'sanctions', 'regime', 'tehran', 'human', 'middle', 'deal']
#
# Topic 230
# ['programme', 'work', 'europe', 'commissions', 'barroso', 'proposals', 'citizens', 'social', 'year', 'constitution']
#
# Topic 231
# ['pttering', 'pm', 'suspended', 'formal', 'harley', 'poettering', 'secretarygeneral', 'pending', 'noon', 'welle']
#
# Topic 232
# ['timor', 'indonesia', 'indonesian', 'east', 'aceh', 'timorese', 'moluccas', 'johannesburg', 'papua', 'international']
#
# Topic 233
# ['diseases', 'tuberculosis', 'malaria', 'health', 'developing', 'aids', 'disease', 'hivaids', 'clinical', 'medicines']
#
# Topic 234
# ['que', 'la', 'jeunesse', 'en', 'los', 'die', 'el', 'lo', 'fragestunde', 'qui']
#
# Topic 235
# ['textile', 'textiles', 'clothing', 'china', 'industry', 'trade', 'imports', 'products', 'sector', 'footwear']
#
# Topic 236
# ['votes', 'details', 'calls', 'results', 'concerning', 'time', 'nbsp', 'procsverbal', 'effectivethere', 'dtails']
#
# Topic 237
# ['pension', 'pensions', 'retirement', 'schemes', 'systems', 'age', 'occupational', 'pillar', 'pensioners', 'pepp']
#
# Topic 238
# ['appointments', 'announcement', 'notified', 'todays', 'delegations', 'date', 'effect', 'changes', 'committees', 'relating']
#
# Topic 239
# ['mediterranean', 'barcelona', 'euromediterranean', 'process', 'peace', 'east', 'middle', 'euromed', 'meda', 'israel']
#
# Topic 240
# ['urgent', 'request', 'agriculture', 'rural', 'colino', 'veal', 'ccns', 'regulation', 'com', 'beef']
#
# Topic 241
# ['mircea', 'pacu', 'ioan', 'suspended', 'presiden', 'podimata', 'anni', 'pm', 'interrupted', 'moments']
#
# Topic 242
# ['biodiversity', 'park', 'species', 'nature', 'loss', 'virunga', 'habitats', 'biological', 'ecosystems', 'natura']
#
# Topic 243
# ['entschlieungen', 'sitzung', 'gremien', 'genehmigung', 'bermitteln', 'genannten', 'einwnde', 'angenommenen', 'sitzungen', 'vorgelegt']
#
# Topic 244
# ['danube', 'roma', 'wine', 'atlantic', 'endocrine', 'strategy', 'thalidomide', 'region', 'river', 'disruptors']
#
# Topic 245
# ['canary', 'overseas', 'mayotte', 'islands', 'regions', 'french', 'rum', 'tax', 'products', 'outermost']
#
# Topic 246
# ['presidenza', 'vice', 'dellonroberta', 'pm', 'angelilli', 'interrupted', 'suspended', 'dellonantonio', 'dellongianni', 'tajani']
#
# Topic 247
# ['declare', '', '', '', '', '', '', '', '', '']
#
# Topic 248
# ['korwinmikke', 'sanction', 'penalty', 'allowance', 'days', 'entitlement', 'subsistence', 'notified', 'consists', 'presidium']
#
# Topic 249
# ['ordinary', 'acts', 'inform', 'adjournment', 'published', 'legislative', 'wednesday', 'sign', 'parliaments', 'accordance']
#
# Topic 250
# ['codification', 'texts', 'regulation', 'coding', 'acts', 'cadmium', 'imports', 'existing', 'codify', 'dumping']
#
# Topic 251
# ['waived', 'immunity', 'request', 'competent', 'parliamentary', 'referred', 'received', 'affairs', 'requests', 'authorities']
#
# Topic 252
# ['copyright', 'authors', 'works', 'music', 'artists', 'creators', 'digital', 'collective', 'cultural', 'creative']
#
# Topic 253
# ['parties', 'political', 'transnational', 'party', 'lists', 'foundations', 'statute', 'funding', 'democracy', 'national']
#
# Topic 254
# ['portuguese', 'treaty', 'presidency', 'barroso', 'europe', 'lisbon', 'intergovernmental', 'macao', 'prodi', 'enlargement']
#
# Topic 255
# ['austrian', 'presidency', 'austria', 'vienna', 'chancellor', 'europe', 'schssel', 'enlargement', 'summit', 'constitution']
#
# Topic 256
# ['payment', 'payments', 'card', 'cards', 'fees', 'transactions', 'debit', 'electronic', 'consumers', 'interbank']
#
# Topic 257
# ['suspended', 'concludes', 'moments', 'voting', 'ends', 'elnkl', 'alelnk', 'vietnieks', 'sdi', 'prieksdtjas']
#
# Topic 258
# ['la', 'que', 'die', 'en', 'des', 'les', 'und', 'et', 'der', 'le']
#
# Topic 259
# ['rainer', 'wieland', 'interrupted', 'pm', 'vice', 'lesson', 'igrene', 'revealedthank', 'zabsk', 'nachhauseweg']
#
# Topic 260
# ['votao', 'perodo', 'segundo', 'sero', 'alterao', 'os', 'votaes', 'resultados', 'declaro', 'comunicados']
#
# Topic 261
# ['switzerland', 'swiss', 'confederation', 'agreement', 'movement', 'asylum', 'tax', 'croatia', 'exchange', 'free']
#
# Topic 262
# ['algeria', 'algerian', 'boualem', 'sansal', 'programs', 'algerians', 'maghreb', 'association', 'euromediterranean', 'algerias']
#
# Topic 263
# ['dellonantonio', 'tajani', 'presidenza', 'chairman', 'craxi', 'singer', 'suspended', 'yvoz', 'pm', 'avena']
#
# Topic 264
# ['aids', 'hiv', 'hivaids', 'infected', 'epidemic', 'treatment', 'prevention', 'disease', 'infections', 'virus']
#
# Topic 265
# ['steel', 'industry', 'industrial', 'metals', 'metal', 'production', 'sector', 'terni', 'carbon', 'jobs']
#
# Topic 266
# ['amending', 'budget', 'budgets', 'conciliation', 'draft', 'lamassoure', 'crche', 'november', 'budgetary', 'definitively']
#
# Topic 267
# ['details', 'follows', 'voting', 'results', 'point', 'beazley', 'rollcall', 'devout', 'votes', 'alvaro']
#
# Topic 268
# ['humanitarian', 'aid', 'volunteers', 'volunteer', 'crises', 'corps', 'disasters', 'summit', 'body', 'conflicts']
#
# Topic 269
# ['sahara', 'morocco', 'western', 'human', 'moroccan', 'nations', 'sahel', 'rights', 'sahrawi', 'united']
#
# Topic 270
# ['onesta', 'pm', 'suspended', 'grard', 'corrections', 'intentions', 'votes', 'voting', '', '']
#
# Topic 271
# ['discharge', 'dec', 'budgetary', 'auditors', 'control', 'budget', 'agencies', 'court', 'year', 'implementation']
#
# Topic 272
# ['puhemies', 'saatavilla', 'istunnon', 'esityslista', 'ja', 'istunto', 'julkaistu', 'alkaen', 'verkkosivustolla', 'parlamentin']
#
# Topic 273
# ['verbale', 'osservazioni', 'processo', 'sono', 'approvati', 'seduta', 'testi', 'distribuiti', 'approvato', 'presidente']
#
# Topic 274
# ['accounting', 'ifrs', 'standards', 'iasb', 'reporting', 'corporate', 'shareholders', 'governance', 'financial', 'companies']
#
# Topic 275
# ['insolvency', 'requirements', 'crr', 'bankruptcy', 'investment', 'securities', 'settlement', 'clearing', 'capital', 'prudential']
#
# Topic 276
# ['china', 'chinese', 'economy', 'wto', 'dumping', 'status', 'chinas', 'trade', 'market', 'steel']
#
# Topic 277
# ['wine', 'wines', 'flavored', 'quality', 'winemaking', 'ros', 'absinthe', 'traditional', 'production', 'sparkling']
#
# Topic 278
# ['bangladesh', 'bangladeshi', 'government', 'elections', 'violence', 'human', 'opposition', 'rights', 'country', 'author']
#
# Topic 279
# ['torture', 'cia', 'guantnamo', 'senate', 'detention', 'prisoners', 'secret', 'terrorism', 'interrogation', 'human']
#
# Topic 280
# ['bangladesh', 'plaza', 'rana', 'textile', 'factories', 'clothing', 'factory', 'companies', 'collapse', 'workers']
#
# Topic 281
# ['yemen', 'saudi', 'humanitarian', 'arabia', 'yemeni', 'conflict', 'civilians', 'coalition', 'situation', 'arms']
#
# Topic 282
# ['interpreters', 'pm', 'sleep', 'night', 'thank', 'nights', 'blessed', 'interpreter', 'close', 'wish']
#
# Topic 283
# ['pm', 'suspended', 'cocilovo', 'esplanade', 'resume', 'garage', 'adjourn', 'opened', 'vice', 'resumes']
#
# Topic 284
# ['hong', 'sport', 'kong', 'az', 'hogy', 'je', 'la', 'des', 'na', 'que']
#
# Topic 285
# ['votazioni', 'dettagli', 'vedasi', 'riguardano', 'verbale', 'risultati', 'reca', 'turno', 'lordine', 'processo']
#
# Topic 286
# ['presidncia', 'vicepresidente', 'silva', 'pereira', 'pedro', 'unterbrochen', 'abstimmungsstunde', 'sitzung', 'uhr', 'geschlossen']
#
# Topic 287
# ['philippines', 'philippine', 'partnership', 'extrajudicial', 'agreement', 'indonesia', 'cooperation', 'republic', 'framework', 'human']
#
# Topic 288
# ['details', 'votes', 'results', 'approved', 'voting', 'rejected', 'original', 'cosigned', 'february', 'reads']
#
# Topic 289
# ['voting', 'details', 'votes', 'results', 'booth', 'screen', 'time', 'painless', 'correctly', 'displaying']
#
# Topic 290
# ['luxembourg', 'presidency', 'juncker', 'europe', 'prime', 'cardiff', 'minister', 'summit', 'enlargement', 'bettel']
#
# Topic 291
# ['aging', 'ageing', 'elderly', 'active', 'older', 'age', 'demographic', 'intergenerational', 'population', 'life']
#
# Topic 292
# ['industrial', 'competitiveness', 'industry', 'compass', 'innovation', 'jobs', 'competitive', 'industries', 'la', 'economy']
#
# Topic 293
# ['maritime', 'erika', 'ships', 'sea', 'hns', 'liability', 'safety', 'oil', 'port', 'tankers']
#
# Topic 294
# ['opened', 'languages', 'morning', 'birthday', 'coofficial', 'afternoon', 'day', 'christmas', 'merry', 'journey']
#
# Topic 295
# ['declare', 'pm', 'opened', 'thursday', 'december', 'elegance', 'soares', 'outgoing', 'oldest', 'impartiality']
#
# Topic 296
# ['india', 'indian', 'euindia', 'scientific', 'summit', 'indias', 'cooperation', 'renewal', 'technological', 'linde']
#
# Topic 297
# ['honey', 'bees', 'beekeepers', 'pollen', 'bee', 'beekeeping', 'ingredient', 'pollinators', 'pollination', 'gmo']
#
# Topic 298
# ['galileo', 'satellite', 'navigation', 'korea', 'gnss', 'gps', 'project', 'egnos', 'space', 'global']
#
# Topic 299
# ['objections', 'recommendation', 'deemed', 'webpage', 'raised', 'pursuant', 'chairs', 'delegated', 'agri', 'threshold']
#
# Topic 300
# ['discrimination', 'equal', 'directive', 'equality', 'treatment', 'disability', 'ethnic', 'religion', 'employment', 'antidiscrimination']
#
# Topic 301
# ['details', 'outcome', 'votes', 'voting', 'time', 'devoted', 'divided', 'federal', 'formal', 'detailed']
#
# Topic 302
# ['barroso', 'commissioners', 'buttiglione', 'europe', 'hearings', 'juncker', 'confidence', 'team', 'house', 'group']
#
# Topic 303
# ['judges', 'court', 'justice', 'number', 'tribunal', 'increase', 'general', 'cases', 'reform', 'service']
#
# Topic 304
# ['belgian', 'belgium', 'prime', 'presidency', 'minister', 'leterme', 'europe', 'la', 'en', 'et']
#
# Topic 305
# ['pm', 'suspended', 'mauro', 'poettering', 'formal', '', '', '', '', '']
#
# Topic 306
# ['biofuels', 'biogas', 'renewable', 'greenhouse', 'emissions', 'energy', 'production', 'biofuel', 'fuels', 'generation']
#
# Topic 307
# ['berichtigung', 'der', 'gem', 'erffnung', 'absatz', 'artikel', 'bekannt', 'angenommen', 'geschftsordnung', 'mitteilen']
#
# Topic 308
# ['arctic', 'greenland', 'northern', 'region', 'dimension', 'indigenous', 'ice', 'resources', 'baltic', 'oil']
#
# Topic 309
# ['sis', 'schengen', 'ii', 'coelho', 'evaluation', 'controls', 'data', 'resettlement', 'borders', 'information']
#
# Topic 310
# ['rouek', 'suspended', 'libor', 'oldich', 'vlask', 'kochmehrin', 'roure', '', '', '']
#
# Topic 311
# ['nepal', 'nepalese', 'maoist', 'king', 'maoists', 'tibetans', 'kathmandu', 'tibetan', 'nepals', 'government']
#
# Topic 312
# ['shipbuilding', 'shipyards', 'shipyard', 'industry', 'korea', 'aid', 'gdask', 'polish', 'yards', 'korean']
#
# Topic 313
# ['postal', 'service', 'services', 'universal', 'mail', 'liberalisation', 'post', 'ferber', 'competition', 'operators']
#
# Topic 314
# ['maternity', 'leave', 'treaty', 'parties', 'intergovernmental', 'parliaments', 'constitution', 'income', 'convention', 'poverty']
#
# Topic 315
# ['aviation', 'emissions', 'icao', 'flights', 'greenhouse', 'trading', 'air', 'ets', 'emission', 'climate']
#
# Topic 316
# ['vietnam', 'laos', 'vietnamese', 'human', 'freedom', 'rights', 'somphone', 'religious', 'hanoi', 'nguyen']
#
# Topic 317
# ['auschwitz', 'holocaust', 'antisemitism', 'jewish', 'jews', 'memory', 'srebrenica', 'camp', 'racism', 'genocide']
#
# Topic 318
# ['chechnya', 'chechen', 'russian', 'russia', 'osce', 'war', 'humanitarian', 'russians', 'caucasus', 'chechens']
#
# Topic 319
# ['patent', 'patents', 'software', 'inventions', 'patenting', 'patentability', 'invention', 'patentable', 'directive', 'computerimplemented']
#
# Topic 320
# ['wallis', 'diana', 'suspended', 'pm', 'concludes', 'declare', '', '', '', '']
#
# Topic 321
# ['suspended', 'pittella', 'mairead', 'mcguinness', 'gianni', 'pm', 'cocilovo', 'luigi', 'morgantini', 'concludes']
#
# Topic 322
# ['ebola', 'epidemic', 'virus', 'health', 'liberia', 'sierra', 'leone', 'outbreak', 'guinea', 'affected']
#
# Topic 323
# ['montenegro', 'montenegros', 'montenegrin', 'progress', 'corruption', 'accession', 'negotiations', 'country', 'adhesion', 'process']
#
# Topic 324
# ['voting', 'lesson', 'details', 'results', 'jewish', 'point', 'hintshe', 'rosh', 'hashanah', 'carver']
#
# Topic 325
# ['impact', 'smes', 'assessment', 'small', 'assessments', 'companies', 'basle', 'administrative', 'burden', 'bureaucracy']
#
# Topic 326
# ['alejo', 'vidalquadras', 'suspended', 'metsola', 'eside', 'roberta', 'completes', 'arena', 'concludes', 'explanation']
#
# Topic 327
# ['buzek', 'opened', 'onyszkiewicz', 'provan', '', '', '', '', '', '']
#
# Topic 328
# ['treaties', 'efsi', 'interinstitutional', 'coelho', 'treaty', 'force', 'codecision', 'legal', 'basis', 'necessitatis']
#
# Topic 329
# ['inland', 'waterways', 'transport', 'budapest', 'navigation', 'waterway', 'goods', 'convention', 'austria', 'belgium']
#
# Topic 330
# ['summit', 'global', 'globalisation', 'crisis', 'growth', 'world', 'economic', 'financial', 'tax', 'pittsburgh']
#
# Topic 331
# ['couples', 'property', 'registered', 'applicable', 'marriage', 'recognition', 'documents', 'regimes', 'matrimonial', 'partnerships']
#
# Topic 332
# ['merkel', 'chancellor', 'europe', 'german', 'berlin', 'presidency', 'french', 'treaty', 'constitution', 'france']
#
# Topic 333
# ['reads', 'objections', 'human', 'cautions', 'rights', 'brunner', 'echerer', 'topical', 'accepted', 'dancona']
#
# Topic 334
# ['budget', 'refugee', 'million', 'flexibility', 'migration', 'euros', 'eur', 'unforeseen', 'margin', 'instrument']
#
# Topic 335
# ['verbal', 'distributed', 'approved', 'observations', 'texts', 'memorabilia', 'observationsthere', 'amazon', 'soviet', 'process']
#
# Topic 336
# ['disease', 'vaccination', 'footandmouth', 'outbreak', 'animals', 'virus', 'animal', 'vaccinated', 'poultry', 'veterinary']
#
# Topic 337
# ['endocrine', 'disruptors', 'dehp', 'substances', 'criteria', 'chemicals', 'scientific', 'properties', 'hormone', 'health']

# %%
# import keywords file to see which topics could be transport related
with open('data/keywords_full.json', 'r', encoding='utf-8') as f:
    keywords_full = set(json.load(f))

# %%
# Find transport-related topics
def is_transport_topic(topic_id, min_keywords=3):
    if topic_id == -1:  # Skip outlier topic
        return False
    
    # Get topic words
    topic_words = bertopic_model.get_topic(topic_id)
    words = ' '.join([word.lower() for word, score in topic_words])
    
    # Count matching keywords
    match_count = sum(1 for keyword in keywords_full if keyword in words)
    
    return match_count >= min_keywords

# Identify transport topics
transport_topic_ids = []
for topic_id in topic_info['Topic']:
    if is_transport_topic(topic_id):
        transport_topic_ids.append(topic_id)
        topic_words = bertopic_model.get_topic(topic_id)
        print(f"Topic {topic_id}: {[word for word, score in topic_words[:10]]}")

print(f"\nFound {len(transport_topic_ids)} transport-related topics: {transport_topic_ids}")
# Out:
# Topic 21: ['air', 'aviation', 'airlines', 'passengers', 'airports', 'aircraft', 'safety', 'airport', 'flight', 'transport']
# Topic 36: ['road', 'vehicles', 'drivers', 'ecall', 'safety', 'traffic', 'roads', 'driving', 'transport', 'vehicle']
# Topic 64: ['transport', 'infrastructure', 'mobility', 'traffic', 'transeuropean', 'projects', 'networks', 'road', 'network', 'multimodal']
# Topic 69: ['railway', 'rail', 'transport', 'railways', 'freight', 'passenger', 'interoperability', 'package', 'train', 'passengers']
#
# Found 4 transport-related topics: [21, 36, 64, 69]

# %%
df["is_bertopic"] = df["bertopic_topic"].isin(transport_topic_ids)

print(f"\nRows flagged as transport by BERTopic: {df['is_bertopic'].sum()}")
# Out:
# Rows flagged as transport by BERTopic: 371

# %%
df[df["is_bertopic"] == True].head()
# Out:
#            date                                              topic  \
# 36   04-05-1999               11. Charging of heavy goods vehicles
# 63   15-04-1999               4. Transport infrastructure charging
# 65   15-04-1999  6. Transport infrastructure charging (continua...
# 70   15-04-1999                      11. TOPICAL AND URGENT DEBATE
# 156  09-03-1999               14. Transportable pressure equipment
#
#                                                   text   term  \
# 36   President . – The next item is the recommendat...  94_99
# 63   President . – The next item is the report (A4‐...  94_99
# 65   President . – The next item is the continuatio...  94_99
# 70   President . – The next item is the debate on t...  94_99
# 156  President . – The next item is the recommendat...  94_99
#
#                                             clean_text  bertopic_topic  \
# 36   recommendation transport tourism common positi...              36
# 63   schmidbauer transport tourism white paper enti...              64
# 65   continuation schmidbauer transport tourism whi...              64
# 70   topical urgent subjects major importance follo...              36
# 156  recommendation transport tourism common positi...              36
#
#      bertopic_prob  is_bertopic
# 36        0.650979         True
# 63        1.000000         True
# 65        0.914965         True
# 70        0.995196         True
# 156       0.658336         True

# %% [markdown]
# ### Additional Analysis

# %%
bertopic_model.get_representative_docs(21)
# Out:
# ['following reports schmitt regional policy transport tourism regulation establishing common rules field civil aviation creating aviation safety agency com c cod collins regional policy transport tourism communication protection air passengers com c cos schmitt ppede regulation creating aviation safety agency welcomed groups basically regulation needs account points important point liberalised air traffic market rise new competitive pressures risk using competition cut costs cost cuts expense safety say loud clear regulation sign want guarantee uniformly high standard safety eu states future ensure identical state point think important aspect bear mind despite fact receives short shift policy economic policy aspects regulation creating authority accurately agency brings licences permits needed air travel industry uniform licensing means future individual states need repeat entire taken care standard agency point needs highlighting creating agency similar institution agency exists america know fia quite lot clout worldwide represents nation strong economic power europeans obviously limping individual nation states influence unit institution represents states think step right direction discussed meetings endeavoured say improve certain positions sounds think prepared did bad job endeavoured lighten make agency independent felt prime concern sort agency improve air traffic safety tried ensure plenty room manoeuvre know current treaties fully independent agency feel agency leeway carry sort legal supervision sort technical supervision certain secondary areas right saying want independent agency think important said administrative board given stronger remit hand executive director given position allows degree independence head agency important aspect make point addressing endeavoured draw clear dividing lines various areas jurisdiction deliberately avoided accepting seat administrative board instead said want perfectly clear lays basic specifications contact corresponding implementing provisions agency ensure technical details properly regulated summarise running time think regulation right making sure level takes action area great people great people worry say quite unequivocally airspace safety know bounds agency placed level house join voting favour tomorrow collins uen advent competition air transport sector certainly resulted lowering prices air travel million consumers growing dissatisfaction air travellers regard quality service receiving airlines eu important air passengers fully aware legal rights problems arise flights matters addressing deny issue developing deepvein thrombosis concern air passengers calling matter urgency allocate monies eu research budget carry independent evaluation possible public health risks air passengers
#  'sterckx regional policy transport tourism communication economic social regions airline industry single market worldwide challenges com c cos sterckx eldr nl really asking communication does future hold aviation industry key approximately years start liberalisation sector liberalisation point communication set growth process new companies sprung new routes opened new air fares fact place attracted new kind public aviation industry existing large small national airline companies profitable started operate efficiently government funding aspects demonstrate liberalisation stirred market say passengers generally benefited liberalisation example evident benefits business class minor compared passenger categories wonder solid basis aviation industry communication stated fragmentation far pronounced united states number airline companies share global market huge difference stated communication profitability companies considerably american counterparts viability new companies appearing market long solid help wonder operating market years time tenable sustainable growth witnessed sector past decade faced overcrowded airspace say badly managed airspace congested airports contend great importance long make management slot allocations airports think matter life death especially small companies starting aviation industry asked social development rights passengers wanted ask outcome agreement recently reached gibraltar matter way related aviation left important steps need taken liberalisation firstly air traffic control course europeanised topic covered atkins tabling matter tomorrow replace privatisation liberalisation agreed conjunction large political groups clear aspect safety europeanised aviation safety authority set matter urgency obvious states need step far aspects concerned key point communication fact external policy aviation words rights regard countries negotiated bilaterally course determines entire structure aviation industry europe normally speaking liberalisation process companies tend operate tune market liberalised actually quite rare world aviation mergers taken place attempt effect klm alitalia abandoned actual fact number problems related nationality way merger swissair sabena cards rely agreement switzerland discussing week forthcoming referendum switzerland happening companies join forces american counterparts play fiddle americans regard establish common transatlantic air space favour principle wonder rushing things big step considering solid base place aviation industry number complex problems need solved step personally quite suspicious americas nationalism comes transport including aviation negotiations clearly held great deal openness reciprocity companies exactly rights americans negotiations bound break things currently stand aviation capable competing americans open market important pull americans viable industry confined boundaries bilateral agreements skated aspect lucas drafted environment deals length need acknowledge limits environment limits important fact vital need ask following following lucas secondly intermodality highlighted think clear issue proposals promote intermodality trains planes work number areas events conclude saying liberalisation hugely important aware halfway order improve current situation need receive proposals concrete action plans legal texts short term clear states important responsibility great deal depends prepared creating real aviation real aviation industry think tandem work fast score world wait need buried avalanche foster ppede draftsman opinion industry external trade research energy draftsman industry just want pick couple areas think need mentioned today aviation doubt exciting stimulating industries opportunities business job creation decade played major economies countries europe worldwide example aviation uk contributes gbp billion year uk gdp generates supports indirect induced uk jobs transports gbp billions worth uk exports maintaining unrivalled access global ...

# %%
bertopic_model.visualize_topics()

# %% [markdown]
# Based on this visualization we can notice even more topics potentially related to transport, based on their proximity compared to the transport related topics we already detected, therefore they should probably be counted as well. This brings us to an expanded topic list: 21, 27, 36, 64, 69, 227, 315, 329

# %%
bertopic_model.visualize_barchart(topics=[21, 27, 36, 64, 69, 227, 315, 329], n_words=7)

# %%
print(transport_topic_ids)
# Out:
# [21, 36, 64, 69]

# %%
# add more topics based on intertopic distance map
transport_topic_ids = [21, 27, 36, 64, 69, 227, 315, 329]

print(transport_topic_ids)
# Out:
# [21, 27, 36, 64, 69, 227, 315, 329]

# %%
# update is_bertopic column
df["is_bertopic"] = df["bertopic_topic"].isin(transport_topic_ids)

print(f"\nRows flagged as transport by BERTopic: {df['is_bertopic'].sum()}")
# Out:
# Rows flagged as transport by BERTopic: 536

# %%
df[df["is_bertopic"] == True].tail()
# Out:
#              date                                              topic  \
# 22926  12-03-2025  4. Action Plan for the Automotive Industry (de...
# 23114  17-12-2024  18. Towards a shared vision for European touri...
# 23242  23-10-2024  18. Need to strengthen rail travel and the rai...
# 23270  21-10-2024  14. Implementation of the Single European Sky ...
# 23307  08-10-2024  9. The crisis facing the EU’s automotive indus...
#
#                                                     text   term  \
# 22926  President. – The next item on the agenda is th...  24_25
# 23114  Chairman.- The next item on the agenda is the ...  24_25
# 23242  President.- The agenda is questioned by the Co...  24_25
# 23270  Chairwoman.- Another point of the daytime is t...  24_25
# 23307  President. – The next item on the agenda is th...  24_25
#
#                                               clean_text  bertopic_topic  \
# 22926  action plan automotive industry rsp adam szapk...              27
# 23114  chairman commissions announcement common visio...             227
# 23242  questioned commissions theme need strengthen r...              69
# 23270  chairwoman point daytime recommendation drawn ...              21
# 23307  crisis facing eus automotive industry potentia...              27
#
#        bertopic_prob  is_bertopic
# 22926       0.596925         True
# 23114       1.000000         True
# 23242       0.315742         True
# 23270       0.878580         True
# 23307       0.596925         True

# %%
# save updated dataframe with betrtopic results
# if needed as checkpoint
# df.to_csv("data/csv/combined_terms_with_bertopic.csv", index=False)

# %% [markdown]
# ## LDA Model

# %%
# load previously saved dataframe with bertopic results if needed
# df = pd.read_csv("data/csv/combined_terms_with_bertopic.csv")

# %%
# shared functions for LDA and NMF

def display_topics(model, feature_names, n_top_words=10):
    """Display top words for each topic"""
    for topic_idx, topic in enumerate(model.components_):
        top_indices = topic.argsort()[-n_top_words:][::-1]
        top_words = [feature_names[i] for i in top_indices]
        print(f"Topic {topic_idx}: {', '.join(top_words)}")

def assign_transport_topics(df, topic_col, transport_topic_ids, flag_col):
    """Flag documents belonging to transport topics"""
    df[flag_col] = df[topic_col].isin(transport_topic_ids)
    print(f"Transport documents: {df[flag_col].sum()}")
    return df

# %%
# using the same cleaned text from the previous model
count_vectorizer = CountVectorizer(max_df=0.90, min_df=5, max_features=5000, stop_words=list(stop_words))
count_data = count_vectorizer.fit_transform(docs)

# %%
# for number of topics we need to put a higher number than usual
# since the dataset is quite large and bertopic found more than 300 topics
n_topics = 100

# %%
# Train LDA
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42, n_jobs=-1)
lda_topics = lda_model.fit_transform(count_data)

# %%
print("=== LDA Topics ===")
display_topics(lda_model, count_vectorizer.get_feature_names_out(), n_top_words=10)
# Out:
# === LDA Topics ===
# Topic 0: vehicles, tunisia, oil, vehicle, car, cars, olive, motor, tunisian, road
# Topic 1: ireland, irish, uk, northern, british, government, kingdom, people, peace, brexit
# Topic 2: treaty, europe, citizens, political, national, lisbon, states, constitution, parliaments, democratic
# Topic 3: people, employment, young, unemployment, social, jobs, youth, states, europe, work
# Topic 4: regulation, writing, voted, ppe, rules, legislation, new, legal, products, sd
# Topic 5: data, protection, states, personal, citizens, information, security, privacy, united, agreement
# Topic 6: social, economic, employment, growth, policies, policy, strategy, states, poverty, market
# Topic 7: states, legislation, legal, animals, animal, need, rules, law, important, issue
# Topic 8: market, single, internal, companies, services, economy, competition, new, important, consumers
# Topic 93: tourism, passengers, travel, rights, passenger, compensation, transport, tourist, airlines, air
# Topic 94: women, gender, equality, men, womens, equal, discrimination, rights, work, life
# Topic 95: terrorism, fight, money, fraud, corruption, states, terrorist, laundering, sport, financial
# Topic 96: writing, voted, eu, ppe, favor, sd, states, support, supported, guengl
# Topic 97: en, det, vi, och, att, die, fr, und, van, der
# Topic 98: health, care, safety, mental, healthcare, people, diseases, services, healthy, medical
# Topic 99: turkey, turkish, cyprus, negotiations, accession, country, political, eu, process, progress

# %%
df["lda_topic"] = lda_topics.argmax(axis=1)
df["lda_prob"] = lda_topics.max(axis=1)

# %%
df.head()
# Out:
#          date                        topic  \
# 0  07-05-1999                     1. VOTES
# 1  07-05-1999             2. Potato starch
# 2  07-05-1999             3. Hannover 2000
# 3  07-05-1999  4. European textiles market
# 4  06-05-1999   1. Approval of the Minutes
#
#                                                 text   term  \
# 0  President . – We shall now move on to the vote...  94_99
# 1  President . – The next item is the proposal fo...  94_99
# 2  President . – The next item is the report (A4‐...  94_99
# 3  President . – The next item is the joint debat...  94_99
# 4  President . – The Minutes of yesterday's sitti...  94_99
#
#                                           clean_text  bertopic_topic  \
# 0  shall votes regulation ecsc ec euratom incorpo...              11
# 1  regulation amending regulation ec establishing...               4
# 2  hoppenstedt culture youth education media comm...              39
# 3  following b ferrer peijs chanterie group peopl...             235
# 4  distributed spencer ppe chairman foreign affai...              -1
#
#    bertopic_prob  is_bertopic  lda_topic  lda_prob
# 0       0.155931        False         85  0.246812
# 1       0.273608        False         17  0.404205
# 2       0.194263        False         62  0.431773
# 3       1.000000        False         85  0.289002
# 4       0.000000        False         85  0.670585

# %%
# transport topics identified after manual review
lda_transport_topics = [0, 19, 72, 90, 93]
df = assign_transport_topics(df, "lda_topic", lda_transport_topics, "is_lda")
# Out:
# Transport documents: 442

# %%
df[df["is_lda"] == True].tail()
# Out:
#              date                                              topic  \
# 22866  02-04-2025  13. The importance of trans-European transport...
# 23114  17-12-2024  18. Towards a shared vision for European touri...
# 23220  24-10-2024  12. Protecting our oceans: persistent threats ...
# 23242  23-10-2024  18. Need to strengthen rail travel and the rai...
# 23270  21-10-2024  14. Implementation of the Single European Sky ...
#
#                                                     text   term  \
# 22866  President.- The agenda bears the declarations ...  24_25
# 23114  Chairman.- The next item on the agenda is the ...  24_25
# 23220  President.- The agenda questioned the declarat...  24_25
# 23242  President.- The agenda is questioned by the Co...  24_25
# 23270  Chairwoman.- Another point of the daytime is t...  24_25
#
#                                               clean_text  bertopic_topic  \
# 22866  bears importance transe transport infrastructu...              -1
# 23114  chairman commissions announcement common visio...             227
# 23220  questioned protection oceans persistent threat...               0
# 23242  questioned commissions theme need strengthen r...              69
# 23270  chairwoman point daytime recommendation drawn ...              21
#
#        bertopic_prob  is_bertopic  lda_topic  lda_prob  is_lda
# 22866       0.000000        False         19  0.252174    True
# 23114       1.000000         True         93  0.210438    True
# 23220       0.438220        False         90  0.280474    True
# 23242       0.315742         True         19  0.363620    True
# 23270       0.878580         True         72  0.336446    True

# %%
# save updated dataframe with LDA results (and bertopic results if they were already present)
# if needed as checkpoint
# df.to_csv("data/csv/combined_terms_with_lda.csv", index=False)

# %% [markdown]
# ## NMF Model

# %%
# load some of the previously saved dataframes if needed
# df = pd.read_csv("data/csv/combined_terms_with_bertopic.csv")
# df = pd.read_csv("data/csv/combined_terms_with_lda.csv")

# %%
# Vectorize with TF-IDF instead of CountVectorizer for NMF
# same hypermarameter settings as for CountVectorizer and LDA
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=5, max_features=5000, stop_words=list(stop_words))
tfidf_data = tfidf_vectorizer.fit_transform(docs)

# %%
# same number of topics as LDA for comparison
n_topics = 100

# %%
# Train NMF
nmf_model = NMF(n_components=n_topics, random_state=42, init='nndsvda')
nmf_topics = nmf_model.fit_transform(tfidf_data)

# %%
print("=== NMF Topics ===")
display_topics(nmf_model, tfidf_vectorizer.get_feature_names_out(), n_top_words=10)
# Out:
# === NMF Topics ===
# Topic 0: europe, people, citizens, today, world, new, future, years, political, democracy
# Topic 1: que, la, en, los, el, las, para, por, una, se
# Topic 2: details, results, concerning, time, proceed, follows, shall, point, bears, shift
# Topic 3: pm, explain, open, period, explanations, dos, martnez, opens, night, coordination
# Topic 4: elections, political, country, democratic, government, democracy, election, opposition, venezuela, situation
# Topic 5: die, der, und, ist, wir, das, ich, den, zu, prsident
# Topic 6: discharge, agency, budget, execution, financial, auditors, agencies, accounts, year, control
# Topic 7: conference, presidents, thursday, wednesday, group, partsession, tuesday, tomorrow, afternoon, groups
# Topic 8: writing, voted, ppe, favor, eu, sd, favour, guengl, supported, pt
# Topic 9: suspended, moments, deputy, pedro, martnez, noon, sylvie, roberta, pending, karas
# Topic 10: fishing, fish, fishermen, tuna, species, sea, waters, vessels, stocks, sustainable
# Topic 11: fisheries, fish, fishermen, stocks, policy, cfp, community, fleet, sector, common
# Topic 12: energy, renewable, gas, electricity, efficiency, sources, supply, oil, prices, energies
# Topic 13: women, gender, equality, womens, men, violence, equal, girls, female, discrimination
# Topic 14: di, che, il, la, del, presidente, della, le, delle, sono
# Topic 15: trade, wto, countries, international, world, negotiations, commercial, agreements, customs, free
# Topic 16: food, foods, safety, genetically, modified, gmos, feed, labelling, health, meat
# Topic 17: rights, human, fundamental, violations, freedom, democracy, defenders, respect, situation, eu
# Topic 18: opened, formal, noon, distributed, thursday, martin, morning, david, december, nbsp
# Topic 19: programme, work, say, policy, time, think, need, make, way, community
# Topic 20: voting, lesson, bears, follows, point, time, turn, concern, process, application
# Topic 21: la, et, les, des, le, nous, en, que, pour, qui
# Topic 22: transport, rail, railway, passengers, air, traffic, road, freight, tourism, aviation
# Topic 23: euro, monetary, ecb, bank, currency, central, economic, stability, inflation, banks
# Topic 24: ukraine, ukrainian, war, support, aggression, russian, eastern, association, moldova, dear
# Topic 25: fraud, customs, olaf, vat, states, corruption, irregularities, office, prosecutors, control
# Topic 26: market, competition, services, single, internal, companies, markets, service, sector, public
# Topic 27: je, na, se, za, kter, tak, evropsk, pro, si, ale
# Topic 28: social, employment, workers, poverty, labour, work, people, working, unemployment, exclusion
# Topic 68: belarus, prisoners, regime, opposition, sanctions, democratic, political, elections, society, civil
# Topic 69: ombudsman, petitions, citizens, institutions, transparency, complaints, documents, petition, work, public
# Topic 70: china, chinese, taiwan, hong, kong, dialogue, relations, peoples, world, eu
# Topic 71: iran, iranian, regime, sanctions, iraq, islamic, people, middle, women, death
# Topic 72: declare, thursday, open, election, seats, candidates, files, december, july, year
# Topic 73: det, en, och, att, vi, som, het, er, und, om
# Topic 74: schengen, visa, border, borders, citizens, visas, movement, external, sis, controls
# Topic 75: media, freedom, journalists, law, hungary, press, hungarian, democracy, expression, government
# Topic 76: maritime, sea, ships, safety, ports, port, shipping, oil, marine, agency
# Topic 77: agreement, agreements, cooperation, partnership, relations, association, republic, negotiations, conclusion, economic
# Topic 78: cultural, culture, heritage, diversity, creative, languages, programme, audiovisual, education, language
# Topic 79: concludes, explanations, moments, ecr, briefly, time, marc, accepted, pedro, just
# Topic 80: outcome, details, time, proceed, shall, voting, information, conciliation, detailed, related
# Topic 81: research, innovation, programme, program, industry, framework, scientific, researchers, technology, horizon
# Topic 82: humanitarian, syria, iraq, war, aid, international, syrian, refugees, sudan, conflict
# Topic 83: water, waste, environmental, environment, substances, recycling, pollution, plastic, chemicals, hazardous
# Topic 84: court, auditors, appointment, audit, justice, judges, candidate, accounts, candidates, courts
# Topic 85: terrorism, victims, terrorist, silence, attacks, attack, violence, people, terrorists, families
# Topic 86: accession, enlargement, countries, macedonia, romania, croatia, bulgaria, republic, candidate, eu
# Topic 87: georgia, georgian, moldova, azerbaijan, armenia, association, eastern, visa, eu, south
# Topic 88: request, postponement, interinstitutional, approved, postpone, ask, referred, urgent, legislative, rule
# Topic 89: workers, fund, globalization, egf, mobilization, feg, employees, adjustment, labor, company
# Topic 90: os, que, da, para, presidente, na, em, dos, uma, com
# Topic 91: bosnia, herzegovina, balkans, country, western, peace, eu, croatia, albania, reforms
# Topic 92: roma, discrimination, racism, ethnic, integration, minorities, minority, education, people, eu
# Topic 93: death, penalty, pakistan, moratorium, punishment, abolition, torture, sentence, nigeria, sentenced
# Topic 94: smes, investment, small, eib, companies, enterprises, bank, capital, businesses, mediumsized
# Topic 95: ppede, group, pse, democrats, accepted, fr, favour, groups, word, propose
# Topic 96: borrell, cuba, formal, noon, applause, inddem, hold, sanctions, barroso, hamas
# Topic 97: chairman, deputy, pavel, point, day, urgent, website, ended, affairs, order
# Topic 98: agus, ar, seo, na, ag, sin, ir, mar, le, kelly
# Topic 99: house, rules, ask, point, shall, bureau, matter, order, pse, rule

# %%
df["nmf_topic"] = nmf_topics.argmax(axis=1)
df["nmf_prob"] = nmf_topics.max(axis=1)

# %%
# transport topics identified after manual review
nmf_transport_topics = [22, 53, 76]
df = assign_transport_topics(df, "nmf_topic", nmf_transport_topics, "is_nmf")
# Out:
# Transport documents: 592

# %%
df[df["is_nmf"] == True].tail()
# Out:
#              date                                              topic  \
# 22810  06-05-2025  6.1. CO2 emission performance standards for ne...
# 22864  02-04-2025                  11. European oceans pact (debate)
# 22866  02-04-2025  13. The importance of trans-European transport...
# 23242  23-10-2024  18. Need to strengthen rail travel and the rai...
# 23270  21-10-2024  14. Implementation of the Single European Sky ...
#
#                                                     text   term  \
# 22810  The president.-The first vote relates to perfo...  24_25
# 22864  Chairman.- Another point of the program is the...  24_25
# 22866  President.- The agenda bears the declarations ...  24_25
# 23242  President.- The agenda is questioned by the Co...  24_25
# 23270  Chairwoman.- Another point of the daytime is t...  24_25
#
#                                               clean_text  bertopic_topic  \
# 22810  presidentthe relates performance standards emi...              27
# 22864  chairman point program ocean pact rsp adam sza...               0
# 22866  bears importance transe transport infrastructu...              -1
# 23242  questioned commissions theme need strengthen r...              69
# 23270  chairwoman point daytime recommendation drawn ...              21
#
#        bertopic_prob  is_bertopic  lda_topic  lda_prob  is_lda  nmf_topic  \
# 22810       1.000000         True          0  0.398724    True         53
# 22864       0.417640        False         90  0.287918    True         76
# 22866       0.000000        False         19  0.252174    True         22
# 23242       0.315742         True         19  0.363620    True         22
# 23270       0.878580         True         72  0.336446    True         22
#
#        nmf_prob  is_nmf
# 22810  0.031230    True
# 22864  0.039847    True
# 22866  0.063462    True
# 23242  0.067017    True
# 23270  0.026686    True

# %%
# save updated dataframe with NMF results (and bertopic and/or LDA results if they were already present)
# if needed as checkpoint
df.to_csv("data/csv/combined_terms_with_nmf.csv", index=False)

# %% [markdown]
# ## Top2Vec Model

# %%
# load some of the previously saved dataframes if needed
# df = pd.read_csv("data/csv/combined_terms_with_bertopic.csv")
# df = pd.read_csv("data/csv/combined_terms_with_lda.csv")
# df = pd.read_csv("data/csv/combined_terms_with_nmf.csv")

# %%
# again use same docs as before
# docs = df["clean_text"].tolist()

# %%
# train model

top2vec_model = Top2Vec(
    documents=docs,
    speed="learn",
    workers=-1,
    verbose=True
)
# Out:
# 2025-10-18 14:31:24,014 - top2vec - INFO - Pre-processing documents for training
# 2025-10-18 14:33:16,414 - top2vec - INFO - Downloading all-MiniLM-L6-v2 model
# 2025-10-18 14:33:21,144 - top2vec - INFO - Creating joint document/word embedding
# 2025-10-18 14:35:11,004 - top2vec - INFO - Creating lower dimension embedding of documents
# 2025-10-18 14:35:35,960 - top2vec - INFO - Finding dense areas of documents
# 2025-10-18 14:35:47,131 - top2vec - INFO - Finding topics

# %%
print(f"Number of topics found: {top2vec_model.get_num_topics()}")
# Out:
# Number of topics found: 227

# %%
topic_sizes, topic_nums = top2vec_model.get_topic_sizes()

# %%
topic_words, word_scores, topic_nums = top2vec_model.get_topics()

print("\n=== Top2Vec Topics ===")
for words, scores, num in zip(topic_words, word_scores, topic_nums):
    print(f"Topic {num}: {', '.join(words[:10])}")
# Out:
# === Top2Vec Topics ===
# Topic 0: votethis, votes, committeethis, voting, electionsi, parliamentthis, deliberation, ballots, chairmanthis, voteit
# Topic 1: budgetas, budgeti, budgetisation, budgetary, reformsi, budgetand, managementi, agenciesi, committees, budgeting
# Topic 2: legislations, legislationthis, legislationi, parliaments, committees, legislationit, parliamentary, legislative, legislationthe, legislation
# assign topics to documents
topic_nums_assigned, topic_scores, topics_words, word_scores = top2vec_model.get_documents_topics(list(range(len(docs))))

# %%
df["top2vec_topic"] = topic_nums_assigned
df["top2vec_score"] = topic_scores

# %%
top2vec_transport_topics = []

# too many topics for manual inspection, use keyword matching instead
print("\n=== Top2Vec Transport Topics ===")
for words, scores, num in zip(topic_words, word_scores, topic_nums):
    words_str = ' '.join([word.lower() for word in words])
    match_count = sum(1 for keyword in keywords_full if keyword in words_str)
    
    if match_count >= 3: # try out different thresholds
        top2vec_transport_topics.append(num)
        print(f"Topic {num}: {', '.join(words[:10])}")

print(f"\nFound {len(top2vec_transport_topics)} transport-related topics: {top2vec_transport_topics}")
# Out:
# === Top2Vec Transport Topics ===
# Topic 15: transportation, transportthis, transporti, transport, transportthe, motorways, transporters, transportul, highways, transporter
# Topic 41: airlines, airline, aviation, airports, passengers, regulationsi, flights, regulationsthis, regulationi, airport
# Topic 42: maritimes, maritime, tankers, seaports, seafarers, ferries, tanker, shipbuilding, harbours, ships
# Topic 100: railways, railway, rail, railroad, trains, locomotives, transporti, transportation, train, transportthis
#
# Found 4 transport-related topics: [15, 41, 42, 100]

# %%
df["is_top2vec"] = df["top2vec_topic"].isin(top2vec_transport_topics)

# %%
print(f"\nRows flagged as transport by Top2Vec: {df['is_top2vec'].sum()}")
# Out:
# Rows flagged as transport by Top2Vec: 672

# %%
df[df["is_top2vec"] == True].tail()
# Out:
#              date                                              topic  \
# 22723  17-06-2025  18. EU framework conditions for competitive, e...
# 22724  17-06-2025  20. Latest developments on the revision of the...
# 22866  02-04-2025  13. The importance of trans-European transport...
# 23242  23-10-2024  18. Need to strengthen rail travel and the rai...
# 23270  21-10-2024  14. Implementation of the Single European Sky ...
#
#                                                     text   term  \
# 22723  President. – The next item is the debate on th...  24_25
# 22724  The President.- The next point of the agenda f...  24_25
# 22866  President.- The agenda bears the declarations ...  24_25
# 23242  President.- The agenda is questioned by the Co...  24_25
# 23270  Chairwoman.- Another point of the daytime is t...  24_25
#
#                                               clean_text  bertopic_topic  \
# 22723  eu framework conditions competitive efficient ...              64
# 22724  point follows explanations latest developments...              21
# 22866  bears importance transe transport infrastructu...              -1
# 23242  questioned commissions theme need strengthen r...              69
# 23270  chairwoman point daytime recommendation drawn ...              21
#
#        bertopic_prob  is_bertopic  lda_topic  lda_prob  is_lda  nmf_topic  \
# 22723       0.695874         True         34  0.255012   False         22
# 22724       0.161534         True         93  0.553292    True         17
# 22866       0.000000        False         19  0.252174    True         22
# 23242       0.315742         True         19  0.363620    True         22
# 23270       0.878580         True         72  0.336446    True         22
#
#        nmf_prob  is_nmf  top2vec_topic  top2vec_score  is_top2vec
# 22723  0.084211    True             15       0.804255        True
# 22724  0.026698   False             41       0.836053        True
# 22866  0.063462    True            100       0.787515        True
# 23242  0.067017    True            100       0.879598        True
# 23270  0.026686    True             41       0.796716        True

# %%
# save updated dataframe with Top2Vec results (and other model results if they were already present)
# if needed as checkpoint
df.to_csv("data/csv/combined_terms_with_top2vec.csv", index=False)
